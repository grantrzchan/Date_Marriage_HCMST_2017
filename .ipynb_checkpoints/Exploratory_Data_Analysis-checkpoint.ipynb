# %%
#import stata file using pandas
import pandas as pd
raw_data = pd.read_stata('./HCMST_2017_public_data_v1.1_stata/HCMST_2017_draft_v1.1.dta')
raw_data
# Out:
#       CaseID  CASEID_NEW      qflag  weight1  weight1_freqwt  weight2  \
# 0          2     2014039  Qualified      NaN             NaN   0.8945
# 1          3     2019003  Qualified   0.9078         71115.0      NaN
# 2          5     2145527  Qualified   0.7205         56442.0      NaN
# 3          6     2648857  Qualified   1.2597         98682.0   1.3507
# 4          7     2623465  Qualified   0.8686         68044.0      NaN
# ...      ...         ...        ...      ...             ...      ...
# 3505    4304     1228389  Qualified      NaN             NaN   0.6463
# 3506    4305     2480357  Qualified      NaN             NaN   1.1856
# 3507    4307     2090075  Qualified      NaN             NaN   0.7724
# 3508    4309     2914837  Qualified      NaN             NaN   0.6082
# 3509    4311     2747613  Qualified      NaN             NaN   0.5909
#
#       weight1a  weight1a_freqwt  weight_combo  weight_combo_freqwt  ...  \
# ...

# %%
raw_data.shape
# Out:
# (3510, 285)

# %%
raw_data.describe()
# Out:
#             CaseID    CASEID_NEW      weight1  weight1_freqwt     weight2  \
# count  3510.000000  3.510000e+03  2994.000000     2994.000000  551.000000
# mean   2121.318803  2.181073e+06     0.999999    78337.460938    1.000003
# std    1241.582562  6.401295e+05     0.285004    22326.515625    0.908374
# min       2.000000  5.300100e+04     0.264700    20736.000000    0.190300
# 25%    1040.250000  1.825512e+06     0.808000    63297.000000    0.519650
# 50%    2118.500000  2.282692e+06     0.943900    73943.000000    0.713300
# 75%    3189.750000  2.759544e+06     1.142650    89512.250000    1.134700
# max    4311.000000  2.972135e+06     2.671000   209239.000000    7.797400
#
#           weight1a  weight1a_freqwt  weight_combo  weight_combo_freqwt  \
# count  3110.000000      3110.000000   3510.000000          3510.000000
# mean      1.000001     78337.601562      1.000000         69410.132812
# std       0.289889     22709.197266      0.437515         30367.960938
# ...

# %%
raw_data[['Race_1', 'S1', 'S3', 'Q6B']]
# Out:
#      Race_1                    S1   S3                        Q6B
# 0       Yes  No, I am not Married  Yes                        NaN
# 1       Yes     Yes, I am Married  NaN                      White
# 2       Yes     Yes, I am Married  NaN                      White
# 3       Yes  No, I am not Married  Yes                        NaN
# 4       Yes     Yes, I am Married  NaN                      White
# ...     ...                   ...  ...                        ...
# 3505    Yes     Yes, I am Married  NaN                      White
# 3506    Yes  No, I am not Married  NaN                      White
# 3507    Yes     Yes, I am Married  NaN  Black or African American
# 3508    Yes  No, I am not Married  NaN  Asian or Pacific Islander
# 3509    Yes  No, I am not Married  NaN                      White
#
# [3510 rows x 4 columns]

# %%
raw_data['Q6B'].hist(xrot=90)

# %%
raw_data['Race_1'].hist()

# %%
raw_data.columns
# Out:
# Index(['CaseID', 'CASEID_NEW', 'qflag', 'weight1', 'weight1_freqwt', 'weight2',
#        'weight1a', 'weight1a_freqwt', 'weight_combo', 'weight_combo_freqwt',
#        ...
#        'hcm2017q24_met_through_family', 'hcm2017q24_met_through_friend',
#        'hcm2017q24_met_through_as_nghbrs', 'hcm2017q24_met_as_through_cowork',
#        'w6_subject_race', 'interracial_5cat', 'partner_mother_yrsed',
#        'subject_mother_yrsed', 'partner_yrsed', 'subject_yrsed'],
#       dtype='object', length=285)

# %%
raw_data['interracial_5cat'].hist()

# %%
set(raw_data['Q21D_2_Year'])
# Out:
# {'1948',
#  '1950',
#  '1952',
#  '1959',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2015',
#  '2017',
#  'Refused',
#  nan}

# %%
raw_data['ppincimp'].hist(xrot=90)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3510 entries, 0 to 3509
# Columns: 285 entries, CaseID to subject_yrsed
# dtypes: category(243), float32(20), float64(18), int16(2), int32(1), int8(1)
# memory usage: 1.7 MB

# %%
raw_data.describe()
# Out:
#             CaseID    CASEID_NEW      weight1  weight1_freqwt     weight2  \
# count  3510.000000  3.510000e+03  2994.000000     2994.000000  551.000000
# mean   2121.318803  2.181073e+06     0.999999    78337.460938    1.000003
# std    1241.582562  6.401295e+05     0.285004    22326.515625    0.908374
# min       2.000000  5.300100e+04     0.264700    20736.000000    0.190300
# 25%    1040.250000  1.825512e+06     0.808000    63297.000000    0.519650
# 50%    2118.500000  2.282692e+06     0.943900    73943.000000    0.713300
# 75%    3189.750000  2.759544e+06     1.142650    89512.250000    1.134700
# max    4311.000000  2.972135e+06     2.671000   209239.000000    7.797400
#
#           weight1a  weight1a_freqwt  weight_combo  weight_combo_freqwt  \
# count  3110.000000      3110.000000   3510.000000          3510.000000
# mean      1.000001     78337.601562      1.000000         69410.132812
# std       0.289889     22709.197266      0.437515         30367.960938
# ...

# %%
raw_data.corr()
# Out:
#                                 CaseID  CASEID_NEW   weight1  weight1_freqwt  \
# CaseID                        1.000000    0.022345  0.077684        0.077684
# CASEID_NEW                    0.022345    1.000000  0.122398        0.122398
# weight1                       0.077684    0.122398  1.000000        1.000000
# weight1_freqwt                0.077684    0.122398  1.000000        1.000000
# weight2                      -0.013460    0.019548  0.483568        0.483567
# weight1a                      0.071165    0.126618  1.000000        1.000000
# weight1a_freqwt               0.071166    0.126618  1.000000        1.000000
# weight_combo                  0.014999   -0.009852  0.860771        0.860771
# weight_combo_freqwt           0.014999   -0.009852  0.860771        0.860771
# duration                     -0.053196    0.019463 -0.007482       -0.007482
# Q16                           0.046322    0.058450  0.094265        0.094265
# ...

# %%
import seaborn as sns
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(raw_data.corr())

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(raw_data, title='Pandas Profiling Report', html={'style': {'full_width: True'}})

# %%
profile
